# %% [markdown]
# Imports
#
# keras - 1.2.2
#
# theano - 0.9.0
#
# And fcn_keras2 script from the Image Segmentation article repository. For more information, check it out step by step.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image

import numpy as np
import math
import copy

import skimage.io as io
from scipy.io import loadmat
from scipy.misc import bytescale

from keras.models import Sequential, Model
from keras.layers import Input, Dense, Flatten, Dropout, Activation, Lambda, Permute, Reshape
from keras.layers import Convolution2D, ZeroPadding2D, MaxPooling2D, Deconvolution2D, Cropping2D
from keras.layers import merge

from utils import fcn32_blank, fcn_32s_to_16s, prediction

# %% [markdown]
# ## Build model architecture
#
# Basic idea behind this: Decapitate each net by discarding the final classifier layer, and convert all fully connected layers to convolutions, to asign a class probability pixelwise.

# %%
image_size = 64*8 # INFO: initially tested with 256, 448, 512
fcn32model = fcn32_blank(image_size)
fcn16model = fcn_32s_to_16s(fcn32model)
imarr = np.ones((3,image_size,image_size))
imarr = np.expand_dims(imarr, axis=0)

#testmdl = Model(fcn32model.input, fcn32model.layers[10].output) # works fine
testmdl = fcn16model # works fine
testmdl.predict(imarr).shape
if (testmdl.predict(imarr).shape != (1,21,image_size,image_size)):
    print('WARNING: size mismatch will impact some test cases')

# %% [markdown]
# Final structure:

# %%
fcn16model.summary() # visual inspection of model architecture
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# permute_input_2 (InputLayer)     (None, 3, 512, 512)   0
# ____________________________________________________________________________________________________
# permute_2 (Permute)              (None, 3, 512, 512)   0           permute_input_2[0][0]
# ____________________________________________________________________________________________________
# conv1_1 (Convolution2D)          (None, 64, 512, 512)  1792        permute_2[0][0]
# ____________________________________________________________________________________________________
# conv1_2 (Convolution2D)          (None, 64, 512, 512)  36928       conv1_1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_6 (MaxPooling2D)    (None, 64, 256, 256)  0           conv1_2[0][0]
# ____________________________________________________________________________________________________
# conv2_1 (Convolution2D)          (None, 128, 256, 256) 73856       maxpooling2d_6[0][0]
# ____________________________________________________________________________________________________
# conv2_2 (Convolution2D)          (None, 128, 256, 256) 147584      conv2_1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_7 (MaxPooling2D)    (None, 128, 128, 128) 0           conv2_2[0][0]
# ____________________________________________________________________________________________________
# conv3_1 (Convolution2D)          (None, 256, 128, 128) 295168      maxpooling2d_7[0][0]
# ____________________________________________________________________________________________________
# conv3_2 (Convolution2D)          (None, 256, 128, 128) 590080      conv3_1[0][0]
# ____________________________________________________________________________________________________
# conv3_3 (Convolution2D)          (None, 256, 128, 128) 590080      conv3_2[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_8 (MaxPooling2D)    (None, 256, 64, 64)   0           conv3_3[0][0]
# ____________________________________________________________________________________________________
# conv4_1 (Convolution2D)          (None, 512, 64, 64)   1180160     maxpooling2d_8[0][0]
# ____________________________________________________________________________________________________
# conv4_2 (Convolution2D)          (None, 512, 64, 64)   2359808     conv4_1[0][0]
# ____________________________________________________________________________________________________
# conv4_3 (Convolution2D)          (None, 512, 64, 64)   2359808     conv4_2[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_9 (MaxPooling2D)    (None, 512, 32, 32)   0           conv4_3[0][0]
# ____________________________________________________________________________________________________
# conv5_1 (Convolution2D)          (None, 512, 32, 32)   2359808     maxpooling2d_9[0][0]
# ____________________________________________________________________________________________________
# conv5_2 (Convolution2D)          (None, 512, 32, 32)   2359808     conv5_1[0][0]
# ____________________________________________________________________________________________________
# conv5_3 (Convolution2D)          (None, 512, 32, 32)   2359808     conv5_2[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_10 (MaxPooling2D)   (None, 512, 16, 16)   0           conv5_3[0][0]
# ____________________________________________________________________________________________________
# fc6 (Convolution2D)              (None, 4096, 16, 16)  102764544   maxpooling2d_10[0][0]
# ____________________________________________________________________________________________________
# fc7 (Convolution2D)              (None, 4096, 16, 16)  16781312    fc6[0][0]
# ____________________________________________________________________________________________________
# score_fr (Convolution2D)         (None, 21, 16, 16)    86037       fc7[0][0]
# ____________________________________________________________________________________________________
# score2 (Deconvolution2D)         (None, 21, 34, 34)    7077        score_fr[0][0]
# ____________________________________________________________________________________________________
# score_pool4 (Convolution2D)      (None, 21, 32, 32)    10773       maxpooling2d_9[0][0]
# ____________________________________________________________________________________________________
# cropping2d_3 (Cropping2D)        (None, 21, 32, 32)    0           score2[0][0]
# ____________________________________________________________________________________________________
# merge_2 (Merge)                  (None, 21, 32, 32)    0           score_pool4[0][0]
#                                                                    cropping2d_3[0][0]
# ____________________________________________________________________________________________________
# upsample_new (Deconvolution2D)   (None, 21, 528, 528)  451605      merge_2[0][0]
# ____________________________________________________________________________________________________
# cropping2d_4 (Cropping2D)        (None, 21, 512, 512)  0           upsample_new[0][0]
# ====================================================================================================
# Total params: 134,816,036
# Trainable params: 134,816,036
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %% [markdown]
# Load VGG weigths from the pre-trained model.
#
# Source: http://www.vlfeat.org/matconvnet/pretrained/#semantic-segmentation

# %%
data = loadmat('models/pascal-fcn16s-dag.mat', matlab_compatible=False, struct_as_record=False)
l = data['layers']
p = data['params']
description = data['meta'][0,0].classes[0,0].description
l.shape, p.shape, description.shape
# Out:
# ((1, 42), (1, 38), (1, 21))

# %% [markdown]
# Classes in this model:

# %%
class2index = {}
for i, clname in enumerate(description[0,:]):
    class2index[str(clname[0])] = i
    
print(sorted(class2index.keys()))
# Out:
# ['aeroplane', 'background', 'bicycle', 'bird', 'boat', 'bottle', 'bus', 'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike', 'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tvmonitor']

# %%
# documentation for the dagnn.Crop layer :
# https://github.com/vlfeat/matconvnet/blob/master/matlab/%2Bdagnn/Crop.m

# %%
def copy_mat_to_keras(kmodel):
    
    kerasnames = [lr.name for lr in kmodel.layers]

    prmt = (3,2,0,1) # WARNING : important setting as 2 of the 4 axis have same size dimension
    
    for i in range(0, p.shape[1]-1, 2):
        matname = '_'.join(p[0,i].name[0].split('_')[0:-1])
        if matname in kerasnames:
            kindex = kerasnames.index(matname)
            print 'found : ', (str(matname), kindex)
            l_weights = p[0,i].value
            l_bias = p[0,i+1].value
            f_l_weights = l_weights.transpose(prmt)
            f_l_weights = np.flip(f_l_weights, 2)
            f_l_weights = np.flip(f_l_weights, 3)
            assert (f_l_weights.shape == kmodel.layers[kindex].get_weights()[0].shape)
            assert (l_bias.shape[1] == 1)
            assert (l_bias[:,0].shape == kmodel.layers[kindex].get_weights()[1].shape)
            assert (len(kmodel.layers[kindex].get_weights()) == 2)
            kmodel.layers[kindex].set_weights([f_l_weights, l_bias[:,0]])
        else:
            print 'not found : ', str(matname)

# %%
#copy_mat_to_keras(fcn32model)
copy_mat_to_keras(fcn16model)
# Out:
# found :  ('conv1_1', 2)
# found :  ('conv1_2', 3)
# found :  ('conv2_1', 5)
# found :  ('conv2_2', 6)
# found :  ('conv3_1', 8)
# found :  ('conv3_2', 9)
# found :  ('conv3_3', 10)
# found :  ('conv4_1', 12)
# found :  ('conv4_2', 13)
# found :  ('conv4_3', 14)
# found :  ('conv5_1', 16)
# found :  ('conv5_2', 17)
# found :  ('conv5_3', 18)
# found :  ('fc6', 20)
# found :  ('fc7', 21)
# found :  ('score_fr', 22)
# found :  ('score2', 23)
# found :  ('score_pool4', 24)
# found :  ('upsample_new', 27)

# %% [markdown]
# ## Image segmentation

# %% [markdown]
# #### Load Image

# %%
im = Image.open('images/rgb.jpg') # http://www.robots.ox.ac.uk/~szheng/crfasrnndemo/static/rgb.jpg
im = im.crop((0,0,319,319)) # WARNING : manual square cropping
im = im.resize((image_size,image_size))
plt.imshow(np.asarray(im))
print(np.asarray(im).shape)
# Out:
# (512, 512, 3)

# %% [markdown]
# #### Pixel prediction

# %%
crpim = im # WARNING : we deal with cropping in a latter section, this image is already fit
preds = prediction(fcn16model, crpim, transform=True)

# %% [markdown]
# #### Plot prediction

# %%
#imperson = preds[0,class2index['person'],:,:]
imclass = np.argmax(preds, axis=1)[0,:,:]

plt.figure(figsize = (15, 7))
plt.subplot(1,3,1)
plt.imshow( np.asarray(crpim) )
plt.subplot(1,3,2)
plt.imshow( imclass )
plt.subplot(1,3,3)
plt.imshow( np.asarray(crpim) )
masked_imclass = np.ma.masked_where(imclass == 0, imclass)
#plt.imshow( imclass, alpha=0.5 )
plt.imshow( masked_imclass, alpha=0.5 )

# %%
# List of dominant classes found in the image
for c in np.unique(imclass):
    print c, str(description[0,c][0])
# Out:
# 0 background
# 2 bicycle
# 14 motorbike
# 15 person

# %% [markdown]
# #### Bytescale values per relevant class

# %%
bspreds = bytescale(preds, low=0, high=255)

plt.figure(figsize = (15, 7))
plt.subplot(2,3,1)
plt.imshow(np.asarray(crpim))
plt.subplot(2,3,3+1)
plt.imshow(bspreds[0,class2index['background'],:,:], cmap='seismic')
plt.subplot(2,3,3+2)
plt.imshow(bspreds[0,class2index['person'],:,:], cmap='seismic')
plt.subplot(2,3,3+3)
plt.imshow(bspreds[0,class2index['bicycle'],:,:], cmap='seismic')

# %% [markdown]
# #### Load Image

# %%
im = Image.open('images/cows.jpg') # http://www.robots.ox.ac.uk/~szheng/crfasrnndemo/static/rgb.jpg
im = im.crop((0,0,319,319)) # WARNING : manual square cropping
im = im.resize((image_size,image_size))
plt.imshow(np.asarray(im))
print(np.asarray(im).shape)
# Out:
# (512, 512, 3)

# %% [markdown]
# #### Pixel prediction

# %%
crpim = im # WARNING : we deal with cropping in a latter section, this image is already fit
preds = prediction(fcn16model, crpim, transform=False) # WARNING : transfrom=True requires a code change (dim order)

# %% [markdown]
# #### Plot prediction

# %%
import matplotlib.patches as mpatches
imclass = np.argmax(preds, axis=1)[0,:,:]
# List of dominant classes found in the image
d={}
values = np.unique(imclass)
for c in values:
    d[c] =str(description[0,c][0])
plt.figure(figsize = (15, 7))
plt.subplot(1,3,1)
plt.imshow( np.asarray(crpim) )
plt.subplot(1,3,2)
im = plt.imshow( imclass )
plt.subplot(1,3,3)
plt.imshow( np.asarray(crpim) )
masked_imclass = np.ma.masked_where(imclass == 0, imclass)
#plt.imshow( imclass, alpha=0.5 )
plt.imshow( masked_imclass, alpha=0.5 )
colors = [ im.cmap(im.norm(value)) for value in values]
patches = [ mpatches.Patch(color=colors[i], label=d[values[i]]) for i in range(len(values)) ]
plt.legend(handles=patches, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0. )
plt.show()

# %% [markdown]
# #### Bytescale values per relevant class

# %%
bspreds = bytescale(preds, low=0, high=255)

plt.figure(figsize = (15, 7))
plt.subplot(2,2,1)
plt.imshow(np.asarray(crpim))
plt.subplot(2,2,2+1)
plt.imshow(bspreds[0,:,:,class2index['background']], cmap='seismic')
plt.subplot(2,2,2+2)
plt.imshow(bspreds[0,:,:,class2index['cow']], cmap='seismic')
